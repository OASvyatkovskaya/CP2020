# %% [markdown]
# # Метод Монте-Карло в физике

# %% [markdown]
# Методами Монте-Карло называют множество различных методов в совершенно разных областях от физики до экономики. Основная суть этих методов заключается в использовании случайных величин для получения различных состояний исследуемой системы.

# %% [markdown]
# Одно из частых применений метода Монте-Карло в физике состоит в расчете интегралов. При этом действительно полезным и незаменимым метод становится при работе с большим количеством измерений, когда построение обычных квадратур приводит к чересчур  огромным сеткам. Например, уже в случае 10 измерений, задание обычной равномерной решетки шириной в $2^4 = 16$ узлов, приводит к общей сетке размера $2^{40} \simeq 10^{12}$. Массив данных float такого размера будет занимать 4ТБ в памяти компьютера. Оперировать такими интегралами стандартными методами становится принципиально невозможно.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sp
# plt.style.use('ggplot')

# %% [markdown]
# ## Задание 1
# Вычислим объем многомерной сферы в большом количестве измерений.

# %% [markdown]
# ### Задание 1.1
# Напишите функцию, вычисляющую точный объем $d$-мерной сферы с помощью явного выражения.
# Объем многомерной сферы радиуса $R$ в $d$-измерениях дается формулой:
# $$
# V_d = \frac{\pi^{d/2} R^{d}} {\Gamma(1 + d/2)}
# $$
# где $\Gamma(x)$ - гамма функция, значение которой можно получить из scipy.special.

# %%
def getSphereVolumeExact(D, R = 1.0):
    return np.pi**(D / 2) / sp.gamma(1 + D / 2) * R**D

# %% [markdown]
# 1. Проверьте результат для нескольких известных вам значений.
# 2. Построите график V(D)

# %%
D = np.linspace(0, 50, 100)
plt.figure(figsize=(12,8))
plt.plot(D, [getSphereVolumeExact(i) for i in(D)], '-', label='V(D), R = 1', color = 'black')
plt.ylabel('Volume')
plt.xlabel('Number of dimensions')
plt.legend()
plt.show()

# %% [markdown]
# ### Задание 1.2
# Напишите функцию, вычисляющую объем сферы методом Монте-Карло на псевдослучайных числах (используя, например `numpy.random.rand`).

# %%
def getSphereVolumePseudorandom(N, D, R = 1):
    points = np.random.uniform(low=-R, high=R, size=(N,D)) 
    right = []
    for i in range(N):
        if np.linalg.norm(points[i,:]) <= 1:
            right.append(1)
    return 2**D*np.sum(right)/N

# %% [markdown]
# Постройте график зависимости относительной точности $\epsilon$ которая достигается при фиксированном $N$ от размерности сферы $D$. Для относительной точности используйте выражение $\epsilon = (V_{exact} - V_{random})/V_{exact}$.

# %%
N = np.arange(10, 1000)
D = 5
volume = getSphereVolumeExact(D)

plt.figure(figsize=(12,8))
plt.plot(N, [1 - getSphereVolumePseudorandom(n, D) / volume for n in N], '-', label='Error, R = 1, D = %i' % D, color = 'black')
plt.ylabel('Error')
plt.xlabel('Random points amount')
plt.legend()
plt.show()

N = 500
D = np.arange(0, 10)

plt.figure(figsize=(12,8))
plt.plot(D, [1 - getSphereVolumePseudorandom(N, d) / getSphereVolumeExact(d) for d in D], '-', label='Error, R = 1, N = %i' % N, color = 'black')
plt.ylabel('Error')
plt.xlabel('Amount of dimensions')
plt.legend()
plt.show()

# %% [markdown]
# ### Задание 1.3
# Напишите функцию, вычисляющую объем сферы методом Монте-Карло на квазислучайной последовательности Соболя.
#
# Для установки библиотеки `sobol_seq`:
#
#
# выполните `pip install sobol_seq` в Jupyter или
#
# выполните команду `pip install sobol_seq --user` в командном окне (если вы используете Jupyter Notebook в составе Anaconda откройте Anaconda Prompt и выполните команду pip в ней, после чего перезапустите Jupyter Notebook).

# %%
#!pip install sobol_seq <-- uncomment to install sobol_seq
import sobol_seq

# %% [markdown]
# Используйте функцию `i4_sobol_generate`. Документацию по ней можно получить выполнив следующую строчку кода:

# %%
sobol_seq.i4_sobol_generate?

# %%
def getSphereVolumeQuasirandom(N, D, R = 1):
    points = sobol_seq.i4_sobol_generate(D,N) 
    right = []
    for i in range(N):
        if np.linalg.norm(points[i,:]) <= 1:
            right.append(1)
    return 2**D*np.sum(right)/N

# %% [markdown]
# Сравните точность вычисления объема для квазислучайной и псевдослучайной последовательностей, рассчитав  $\epsilon(D)$, при таком же значении $N$, как в предыдущем задании. Постройте обе зависимости $\epsilon(D)$ на одном графике в логарифмической шкале по $\epsilon$.

# %%
N = 500
D = np.arange(1, 10)

plt.figure(figsize=(12,8))
plt.plot(D, [1 - getSphereVolumePseudorandom(N, d) / getSphereVolumeExact(d) for d in D], '-', label='Pseudorandom error, R = 1, N = %i' % N, color = 'black')
plt.plot(D, [1 - getSphereVolumeQuasirandom(N, d) / getSphereVolumeExact(d) for d in D], '-', label='Quasirandom errror, R = 1, N = %i' % N, color = 'red')
plt.ylabel('Volume error')
plt.xlabel('Number of dimensions')
plt.legend()
plt.show()

# %% [markdown]
# Сделайте вывды о работе псевдослучайной и квазислучайной последовательностях.

# %% [markdown]
# Вообще конечно лучше брать больший набор точек и использовать метод Соболя, он стабильнее.

# %% [markdown]
# ## Задание 2
#
# Рассмотрим решетку $n\times n$, в которой каждой ячейке соответствует спин $\sigma_i$ равный $+1$ или $-1$. При этом между соседними ячейками существует энергия взаимодействия
# $$
# E_i = -J \sigma_i \sigma_j
# $$
# Тогда энергия каждой ячейки
# $$
# E_i = -J \sigma_i \sum_j \sigma_j
# $$
# где суммирование подразумевается только по соседним с $i$-ой ячейкой.
#
# При нулевой температуре энергитически более выгодным состоянием является состояние, когда все спины одинаково ориентированы. Однако при ненулевой температуре вероятность перехода в более возбужденное состояние пропорциональна $\sim \exp(-\Delta E/ k T)$.
#
# Явное численное моделирование такой системы (модели Изинга) является проблематичным, поскольку количество возможных состояний системы $2^N$, где $N$ - общее число узлов, и уже для двумерной сетки $16\times 16$ это число становится астрономически большим.

# %% [markdown]
# На помощь приходят методы Монте-Карло. Одна из простейших его реализаций (алгоритм Метрополиса — Гастингса):
# 1. Задаем случайное начальное состояние
# 2. Выбираем случайную ячейку
# 3. Переворачиваем её спин и считаем изменение энергии $\delta E$ данной ячейки.
# 4. Если изменение энергии отрицательное, оставляем спин перевернутым
# 5. Если изменение энергии положительное, оставляем спин перевернутым с вероятностью $\exp(-\delta E/kT)$
# 6. Повторяем пункты 2-5 нужное количество раз
#
# Спустя достаточно большое количество повторений устанавливается равновесное состояние.

# %% [markdown]
# Реализуем данный алгоритм:
# 1. Задайте начальное случайное расраспределение в виде матрицы из $+1$ и $-1$ размерности $N\times N$:

# %%
def getInitialState(N):    
    return 2*np.random.randint(-1,1, size=(N,N)) + 1

# %% [markdown]
# 2. Напишите функцию, которая для ячейки $(i,j)$ расчитывает изменение её энергии, если изменить её знак. При этом для простоты предполагаем, во-первых, что $J=1$ (на него отнормируем kT), и во-вторых, что элементы находящиеся на верхней и нижней (левой и правой) границах находятся рядом друг с другом (топология тора).

# %%
def getDeltaE(i, j, state):
    '''
    Функция расчитывает изменение энергии ячейки (i,j) в случае ее переворота (при этом функция сама не меняет сосотояния state)
    ---------
    Аргументы:
    i - int, адресс ячейки вдоль оси 0
    j - int, адресс ячейки вдоль оси 1
    state - numpy ndarray of ints, массив состояния системы размера NxN
    --------
    Функция возвращает:
    dE - float, изменение энергии
    '''
    N = state.shape[0]
    j_ = j if j < N - 1 else 0
    i_ = i if i < N - 1 else 0
    dE = 2 * state[i, j] * (state[i, j - 1] + state[i - 1, j] + state[i, j_] + state[i_, j])
    return dE

# %% [markdown]
# 3. Напишите функцию, которая $N^2$ раз для разных случайных $(i,j)$ меняет спин в зависимости от изменения энергии, согласно пунктам 4. и 5.

# %%
def makeFlip(T, state):
    '''
    Функция расчитывает изменение энергии ячейки (i,j) в случае ее переворота (при этом функция сама не меняет сосотояния state)
    ---------
    Аргументы:
    T - float, положительное число, безразмерный коэфициент, характеризующий температуру, равный kT/J
    state - numpy ndarray of ints, массив состояния системы размера NxN
    --------
    Функция возвращает:
    state - numpy ndarray of ints, массив нового состояния системы размера NxN
    '''
    for k in range(N**2):
        i, j = np.around(N * np.random.rand(2) - 1)
        i = int(i)
        j = int(j)
        dE = getDeltaE(i, j, state)
        if dE < 0:
            state[i, j] = -state[i, j]
        else:
            poss = np.exp(-dE / T)
            ran = np.random.rand()
            if ran < poss:
                state[i, j] = -state[i, j]
    return state

# %% [markdown]
# 4. Напишите функцию, которая будет рассчитывать значение энергии всей системы (предполагаем $J=1$).

# %%
def getEnergy(state):
    '''
    Функция, рассчитывает значение энергии всей системы
    ---------
    Аргументы:
    state - numpy ndarray of ints, массив состояния системы размера NxN
    --------
    Функция возвращает:
    E - float, значение энергии системы
    '''
    E = 0
    N = len(state)
    #по факту мы уже считали это. Нам просто надо взять не 2Е, а просто Е да еще с обратным знаком
    for i in range(N):
        for j in range(N):
            E += -1/2*getDeltaE(i, j, state)
    return E

# %% [markdown]
# 5. Напишите функцию, которая будет рассчитывать значение намагниченности всей системы $M=\sum \sigma$

# %%
def getMagnetization(state):    
    '''
    Функция, рассчитывает значение намагниченности всей системы
    ---------
    Аргументы:
    state - numpy ndarray of ints, массив состояния системы размера NxN
    --------
    Функция возвращает:
    M - float, значение намагниченности системы
    '''
    return np.sum(state)

# %% [markdown]
# В следующей ячейке кода зададим начальные параметры:
#
# **Nt** - количество точек по температуре,
#
# **N** - линейный размер решетки,
#
# **eqStep** - количество попыток переворота спина, в течение которых система приводится к равновесному сосотоянию. Обратите внимание, что это число должно увеличиваться пропорционально размеру всей сетки,
#
# **steps** - количество попыток переворота спина, в течение которых рассчитывается значения энергии и намагниченности (нужно для усреднения расчитанных значений по ансамблю состояний, близких к равновесному)

# %%
N       = 10         # размер решетки NxN
Nt      = 100         # количество точек температуры
eqSteps = 200        # количество раз выполнения makeFlip для установления равновесия
steps   = 50         # количество раз выполнения makeFlip для усреднения энергии и намагниченности

T = np.linspace(0.5, 5, Nt); 
E, M = np.zeros(Nt), np.zeros(Nt)

# %%
for t in range(Nt):
    print(('Complete %.1f %%\r' % (t/Nt*100)), end='')
    
    Esum = Msum = 0
    state = getInitialState(N)
    
    for i in range(eqSteps):         # установление статистического равновесия
        makeFlip(T[t], state)          

    for i in range(steps):           # суммирование по разным состояниям близким к равновеснсому
        makeFlip(T[t], state)          
        Esum += getEnergy(state)       
        Msum += getMagnetization(state) 

    E[t] = Esum / (steps * N * N)
    M[t] = Msum / (steps * N * N)

print("Done              \r", end='')

_, ax = plt.subplots(1,2,figsize=(10, 5));

ax[0].scatter(T, E)
ax[0].set_xlabel("Temperature");
ax[0].set_ylabel("Energy ");

ax[1].scatter(T, abs(M), color = 'blue')
ax[1].set_xlabel("Temperature"); 
ax[1].set_ylabel("Magnetization ");
# Out:
# Done

# %% [markdown]
# Интерпретируйте с точки зрения физики полученные графики. Описывают ли они поведение ферромагнетиков и фазовые переходы?

# %% [markdown]
# Известно, что магнитное поле влияет на вращение спинов (они поворачиваются к внешнему полю). В то же время, кинетическая энергия не дает им оставаться в одном состоянии. Поэтому наиболее выгодное состояние из энергетических соображений- когда большая часть спинов повернуты к полю (видно на низких температурах) Для высоких температур нет намагничивания. As we know, magentic field affects the state of the molecular magnetic features of an object, so the molecular spins will rotate towards the external field. But the kinetic energy prevents it from staying in that one state. As a result, the most energy-optimal state is when mostly every spin "looking" towards the field (the same direction), that can be seen on the low temperatures. The oposite effect can be seen on the high temperatures: no magnetization and higher overall energy.

# %% [markdown]
# Задайте новое сосотояние системы с достаточно большим $N$ и визуализируйте его думя цветами (например с помощью `plt.scatter`). Примените несколько раз к этому сосотоянию функциию makeFlip с низкой и с высокой температурами. Объясните наблюдаемое

# %%
N = 70
state = getInitialState(N)
temp = state

# %%
plt.figure(figsize=(12,8))
plt.plot(np.where(state - 1)[1], np.where(state - 1)[0], '.', color = 'gold')
plt.plot(np.where(state + 1)[1], np.where(state + 1)[0], '.', color = 'black')
plt.title('Initial state')
plt.axis('off')
plt.show()

for i in range(30):
    makeFlip(0.5, state);

# %%
plt.figure(figsize=(12,8))
plt.plot(np.where(state - 1)[1], np.where(state - 1)[0], '.', color = 'gold')
plt.plot(np.where(state + 1)[1], np.where(state + 1)[0], '.', color = 'Black')
plt.title('Low-temprature')
plt.axis('off')
plt.show()

state = temp

for i in range(30):
    makeFlip(100, state);

# %%
plt.figure(figsize=(12,8))
plt.plot(np.where(state - 1)[1], np.where(state - 1)[0], '.', color = 'gold')
plt.plot(np.where(state + 1)[1], np.where(state + 1)[0], '.', color = 'black')
plt.title('High-temprature')
plt.axis('off')
plt.show()

# %% [markdown]
# В случае низких температур образуются группы спинов с одинаковым спиновым значением. В случае высоких температур такого мы наблюдать не можем
